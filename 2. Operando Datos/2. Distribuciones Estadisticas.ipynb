# %% [markdown]
# # Distribuciones Estadisticas

# %% [markdown]
# ### Distribución Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a=1
b=100
n=200
data = np.random.uniform(a,b,n)<

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([22., 22., 21., 20., 25., 18., 21., 12., 14., 25.]),
#  array([ 2.41956958, 12.14259033, 21.86561107, 31.58863182, 41.31165256,
#         51.0346733 , 60.75769405, 70.48071479, 80.20373554, 89.92675628,
#         99.64977703]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Distribución Normal

# %%
data = np.random.randn(1000)

# %%
# %matplotlib inline
x=range(1,1001)
plt.plot(x,data) #Conjuntos de valores que se han obtenido con randn

# %%
plt.hist(data)
# Out:
# (array([  4.,  17.,  74., 183., 267., 225., 151.,  56.,  17.,   6.]),
#  array([-3.22759351, -2.57683222, -1.92607093, -1.27530964, -0.62454835,
#          0.02621294,  0.67697423,  1.32773552,  1.97849681,  2.6292581 ,
#          3.28001939]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x,sorted(data))

# %%
mu = 5.5 
sd= 2.5
data= 5.5 + 2.5*np.random.randn(1000) #Para usar una desviacion standar
#Segun los datos usados

# %%
plt.hist(data)
# Out:
# (array([  3.,  26.,  83., 197., 278., 247., 115.,  45.,   4.,   2.]),
#  array([-2.86546873, -1.10127633,  0.66291606,  2.42710846,  4.19130086,
#          5.95549325,  7.71968565,  9.48387805, 11.24807044, 13.01226284,
#         14.77645524]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Simulación de Monte Carlo

# %% [markdown]
# Generamos dos numeros aleatorios entre 0 y 1
# Calcularemos x * x + y*y
#     * Si el valor es inferior a 1 estamos dentro del circulo
#     * Si es mayor a 1 estamos fuera del circulo
# Calculamos el numero total de veces que estan dentro del circulo y dividimos entre el numero de intentos obtenidos

# %%
def pi_montecarlo(n, n_exp):
    pi_avg=0
    pi_value_list=[]
    n=1000
    for i in range(n_exp):
        value=0
        x = np.random.uniform(0,1,n).tolist()
        y=np.random.uniform(0,1,n).tolist()
        for j in range(n):
            z=np.sqrt(x[j]*x[j] + y[j]*y[j])
            if z<=1:
                value+=1
        float_value= float(value)
        pi_value= (float_value * 4 )/n
        pi_value_list.append(pi_value)
        pi_avg+=pi_value
    pi=pi_avg/n_exp
    fig=plt.plot(pi_value_list)
    return(pi,fig)

# %%
pi_montecarlo(10,10)
# Out:
# (3.144, [<matplotlib.lines.Line2D at 0x27a98326c88>])

# %% [markdown]
# ## Dummy Data Sets

# %%
n=100000
data = pd.DataFrame(
    {
        "A": np.random.randn(n),
        "B": 1.5 +2.5* np.random.randn(n),
        "C": np.random.uniform(5,32,n)
    }
)

# %%
data.describe()
# Out:
#                    A              B              C
# count  100000.000000  100000.000000  100000.000000
# mean       -0.001854       1.491552      18.524972
# std         0.998368       2.507480       7.803685
# min        -4.445822      -8.015186       5.000064
# 25%        -0.671865      -0.205738      11.761374
# 50%        -0.000475       1.487705      18.512375
# 75%         0.668158       3.192937      25.300206
# max         4.203051      11.769268      31.999659

# %%
plt.hist(data.A)
# Out:
# (array([2.2000e+01, 3.1500e+02, 2.8670e+03, 1.3011e+04, 2.9042e+04,
#         3.2078e+04, 1.7274e+04, 4.7360e+03, 6.1700e+02, 3.8000e+01]),
#  array([-4.44582245, -3.58093506, -2.71604768, -1.85116029, -0.98627291,
#         -0.12138552,  0.74350186,  1.60838925,  2.47327663,  3.33816402,
#          4.2030514 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data.B)
# Out:
# (array([  141.,  1198.,  6360., 18631., 29713., 26619., 13172.,  3605.,
#           523.,    38.]),
#  array([-8.01518556, -6.03674023, -4.05829491, -2.07984959, -0.10140426,
#          1.87704106,  3.85548639,  5.83393171,  7.81237703,  9.79082236,
#         11.76926768]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data.C)
# Out:
# (array([ 9982.,  9960., 10067.,  9940., 10002.,  9954.,  9777., 10102.,
#         10207., 10009.]),
#  array([ 5.00006355,  7.70002314, 10.39998272, 13.09994231, 15.79990189,
#         18.49986147, 21.19982106, 23.89978064, 26.59974022, 29.29969981,
#         31.99965939]),
#  <a list of 10 Patch objects>)

# %%
data= pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0       16.78       244.7           91         11.01       10.0           3
# 1       16.62       254.4          103         11.45       13.7           3
# 2       10.30       162.6          104          7.32       12.2           5
# 3        5.26       196.9           89          8.86        6.6           7
# 4       12.61       186.9          121          8.41       10.1           3
#
#    Intl Charge  CustServ Calls  Churn?
# 0         2.70               1  False.
# 1         3.70               1  False.
# 2         3.29               0  False.
# 3         1.78               2  False.
# 4         2.73               3  False.
#
# [5 rows x 21 columns]

# %%
colum_names= data.columns.values.tolist()
a=len(colum_names)

# %%
new_data= pd.DataFrame(
    {
        "Column Name": colum_names,
        "A": np.random.randn(a),
        "B": np.random.uniform(0,1,a)
    }
)

# %%
new_data
# Out:
#        Column Name         A         B
# 0            State -1.251265  0.281728
# 1   Account Length -0.453523  0.925443
# 2        Area Code -0.569059  0.075859
# 3            Phone -0.304813  0.789358
# 4       Int'l Plan  0.816294  0.965207
# 5       VMail Plan -2.026890  0.424839
# 6    VMail Message  1.224676  0.666812
# 7         Day Mins  2.611318  0.716423
# 8        Day Calls -0.495944  0.082342
# 9       Day Charge -0.187672  0.463587
# 10        Eve Mins -1.366761  0.852320
# 11       Eve Calls -0.067656  0.756894
# 12      Eve Charge -2.229791  0.221064
# 13      Night Mins -0.013751  0.839746
# 14     Night Calls  0.456267  0.934833
# 15    Night Charge  0.126038  0.816634
# 16       Intl Mins -0.042035  0.348824
# 17      Intl Calls  0.079942  0.353513
# 18     Intl Charge  1.003358  0.999532
# 19  CustServ Calls  0.741695  0.277453
# 20          Churn? -0.792608  0.193446
